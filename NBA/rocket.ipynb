# %%
print("Happy! NBA")
# Out:
# Happy! NBA

# %%
# 計算圓的面積
radius = 5
pi = 3.14159
area = pi * radius ** 2
print(f"圓的面積是：{area}")

# 判斷數字是否在範圍內
number = 15
if number > 10 and number < 20:
    print("數字在 10 和 20 之間")

# 字串操作
name = "Python"
if "Py" in name:
    print("字串包含 'Py'")
# Out:
# 圓的面積是：78.53975
# 數字在 10 和 20 之間
# 字串包含 'Py'

# %%
a=5+10
b=20-15
print("a=%d, b=%d, a-b=%d" %(a,b,a-b))
c=a-b
b, c
# Out:
# a=15, b=5, a-b=10
# (5, 10)

# %% [markdown]
# # 變數學習

# %%
a=10; b=3
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 3.3333333333333335
# 3
# 1
# 1000

# %%
a,b
# Out:
# (10, 3)
