# %%
total = 0
for i in range(1,1001):
    # print(i)
    total += i
    # print(total)

print(total)
# Out:
# 500500

# %%
# begin = 5
# while(begin<7):
#     print(begin)
#     begin += 1

import random
while True:
    if random.randint(1,10)==5:
        break
    print("不等於5")
    
print("等於5")
# Out:
# 等於5
